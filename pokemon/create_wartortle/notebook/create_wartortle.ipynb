# %% [markdown]
# # Create Wartortle
# Code used for this blog series.
# By editing the config files, we can experiment how different reward setting affects RED's learning.
#
# To run the code, you need to get PokemonRed.gb from web and place it directly under pokemon/create_wartortle directory.

# %%
import os
import sys
import yaml

current_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(current_dir, '..')))
sys.path.append(os.path.abspath(os.path.join(current_dir, '../py')))
sys.path.append(os.path.abspath(os.path.join(current_dir, '../util')))
import td_learning
import pokemon_env
import visualize_value_func

# %%
# Load config
with open('../config/env_config.yaml', 'r') as f:
    env_config = yaml.safe_load(f)

with open('../config/td_learning_config.yaml', 'r') as f:
    td_learning_config = yaml.safe_load(f)
    
with open("../config/vis_config.yaml", 'r') as f:
    vis_config = yaml.safe_load(f)

# %%
# Run TD learning
td_learning.main(env_config, td_learning_config, vis_config)
# Out:
# Run training
# Episode 1/3
# ../state_file/pallet_town_grass.state
# Episode 2/3
# ../state_file/pallet_town_grass.state
# Episode 3/3
# ../state_file/pallet_town_grass.state
